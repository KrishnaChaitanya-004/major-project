# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("kumbakonam.csv")
df = df.dropna()
df = df.sort_values("time")
df.reset_index(drop=True, inplace=True)

df.head()
# Out:
#                   time  temperature   dewpoint    pressure    wind_u  \
# 0  2021-01-01 00:00:00    22.837800  21.194183  1006.72250 -0.126257
# 1  2021-01-01 06:00:00    28.565582  21.591217  1009.07500 -3.449174
# 2  2021-01-01 12:00:00    27.364410  22.757751  1006.35187 -2.203822
# 3  2021-01-01 18:00:00    23.399567  20.992584  1008.41376 -0.920076
# 4  2021-01-02 00:00:00    23.179352  20.367035  1006.64435  0.536304
#
#      wind_v  cloud_cover   humidity   rain_mm
# 0 -3.454937     0.225506  90.464226  0.000000
# 1 -4.246556     0.986888  65.990870  0.038236
# 2 -2.530645     1.000001  75.991110  0.000000
# 3 -3.154928     0.993090  86.367165  0.000000
# 4 -3.508369     1.000001  84.215390  0.000572

# %%
feature_cols = [
    "temperature",
    "dewpoint",
    "pressure",
    "wind_u",
    "wind_v",
    "cloud_cover",
    "humidity"
]

target_col = "rain_mm"

X = df[feature_cols].values
y = df[target_col].values

# %%
split_index = int(len(X) * 0.8)

X_train = X[:split_index]
X_test  = X[split_index:]

y_train = y[:split_index]
y_test  = y[split_index:]

# %%
rf = RandomForestRegressor(
    n_estimators=200,
    max_depth=None,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, n_jobs=-1, random_state=42)

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import (
    r2_score,
    mean_squared_error,
    mean_absolute_error,
    median_absolute_error
)

mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_test, y_pred)
medae = median_absolute_error(y_test, y_pred)
r2   = r2_score(y_test, y_pred)

print("Model Evaluation Results")
print("R²     :", round(r2, 4))
print("MSE    :", round(mse, 4))
print("RMSE   :", round(rmse, 4))
print("MAE    :", round(mae, 4))
print("MedAE  :", round(medae, 4))
# Out:
# Model Evaluation Results
# R²     : 0.1061
# MSE    : 0.1229
# RMSE   : 0.3505
# MAE    : 0.1025
# MedAE  : 0.0208

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
plt.plot(y_test[:200], label="Actual")
plt.plot(y_pred[:200], label="Predicted")
plt.legend()
plt.title("Random Forest Rainfall Prediction")
plt.show()
