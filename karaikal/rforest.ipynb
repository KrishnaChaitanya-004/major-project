# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("karaikal.csv")
df = df.dropna()
df = df.sort_values("time")
df.reset_index(drop=True, inplace=True)

df.head()
# Out:
#                   time  temperature   dewpoint   pressure    wind_u    wind_v  \
# 0  2021-01-01 00:00:00    25.006378  21.004670  1010.6362 -3.620275 -5.611431
# 1  2021-01-01 06:00:00    27.137115  20.595917  1013.3044 -4.586198 -5.499852
# 2  2021-01-01 12:00:00    26.107025  21.898743  1010.6350 -3.636195 -5.447638
# 3  2021-01-01 18:00:00    25.648956  21.057404  1012.3875 -2.965548 -6.047995
# 4  2021-01-02 00:00:00    25.250275  21.408783  1010.4356 -1.692822 -5.638008
#
#    cloud_cover   humidity   rain_mm
# 0     0.447605  78.490326  0.000000
# 1     0.974360  67.477300  0.000000
# 2     1.000001  77.662346  0.108626
# 3     0.997626  75.792270  0.000000
# 4     0.998517  79.300010  0.006484

# %%
feature_cols = [
    "temperature",
    "dewpoint",
    "pressure",
    "wind_u",
    "wind_v",
    "cloud_cover",
    "humidity"
]

target_col = "rain_mm"

X = df[feature_cols].values
y = df[target_col].values

# %%
split_index = int(len(X) * 0.8)

X_train = X[:split_index]
X_test  = X[split_index:]

y_train = y[:split_index]
y_test  = y[split_index:]

# %%
rf = RandomForestRegressor(
    n_estimators=200,
    max_depth=None,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, n_jobs=-1, random_state=42)

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import (
    r2_score,
    mean_squared_error,
    mean_absolute_error,
    median_absolute_error
)

mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_test, y_pred)
medae = median_absolute_error(y_test, y_pred)
r2   = r2_score(y_test, y_pred)

print("Model Evaluation Results")
print("R²     :", round(r2, 4))
print("MSE    :", round(mse, 4))
print("RMSE   :", round(rmse, 4))
print("MAE    :", round(mae, 4))
print("MedAE  :", round(medae, 4))
# Out:
# Model Evaluation Results
# R²     : 0.1372
# MSE    : 0.1674
# RMSE   : 0.4091
# MAE    : 0.1053
# MedAE  : 0.0178

# %%
plt.figure(figsize=(12,5))
plt.plot(y_test[:200], label="Actual")
plt.plot(y_pred[:200], label="Predicted")
plt.legend()
plt.title("Random Forest Rainfall Prediction")
plt.show()
