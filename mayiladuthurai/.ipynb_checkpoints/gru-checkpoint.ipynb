# %%
import os
import random
import numpy as np

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
os.environ["TF_DETERMINISTIC_OPS"] = "1"

import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
SEED = 42

os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

os.environ["TF_DETERMINISTIC_OPS"] = "1"

# %%
df = pd.read_csv("mayiladuthurai.csv")  
df = df.sort_values("time")

df["time"] = pd.to_datetime(df["time"])


feature_cols = [
    "temperature",
    "dewpoint",
    "pressure",
    "wind_u",
    "wind_v",
    "cloud_cover",
    "humidity"
]

target_col = "rain_mm"

# %%
feature_scaler = StandardScaler()
target_scaler = StandardScaler()

X_scaled = feature_scaler.fit_transform(df[feature_cols])
y_scaled = target_scaler.fit_transform(df[[target_col]])

# %%
sequence_length = 12   # 12 timesteps (72 hours)

def create_sequences(X, y, seq_len):
    Xs, ys = [], []
    for i in range(len(X) - seq_len):
        Xs.append(X[i:i+seq_len])
        ys.append(y[i+seq_len])
    return np.array(Xs), np.array(ys)

X_seq, y_seq = create_sequences(X_scaled, y_scaled, sequence_length)

# %%
split_index = int(len(X_seq) * 0.8)

X_train, X_test = X_seq[:split_index], X_seq[split_index:]
y_train, y_test = y_seq[:split_index], y_seq[split_index:]

# %%
model = Sequential([
    GRU(64, return_sequences=True, input_shape=(sequence_length, X_train.shape[2])),
    Dropout(0.2),
    GRU(32),
    Dropout(0.2),
    Dense(16, activation="relu"),
    Dense(1)
])

model.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

model.summary()
# Out:
# /home/kc/py312/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 12, 64)         │        14,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 32)             │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,969 (93.63 KB)
#  Trainable params: 23,969 (93.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

history = model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=64,
    validation_data=(X_test, y_test),
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.8742 - mae: 0.3425 - val_loss: 1.3382 - val_mae: 0.3140
# Epoch 2/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.8552 - mae: 0.3258 - val_loss: 1.3296 - val_mae: 0.3193
# Epoch 3/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.8595 - mae: 0.3255 - val_loss: 1.3276 - val_mae: 0.3152
# Epoch 4/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.8521 - mae: 0.3265 - val_loss: 1.3231 - val_mae: 0.3165
# Epoch 5/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.8512 - mae: 0.3225 - val_loss: 1.3245 - val_mae: 0.3049
# Epoch 6/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.8528 - mae: 0.3228 - val_loss: 1.3201 - val_mae: 0.3141
# Epoch 7/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.8474 - mae: 0.3222 - val_loss: 1.3221 - val_mae: 0.3103
# Epoch 8/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.8407 - mae: 0.3233 - val_loss: 1.3169 - val_mae: 0.3170
# Epoch 9/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.8463 - mae: 0.3218 - val_loss: 1.3219 - val_mae: 0.3135
# Epoch 10/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.8396 - mae: 0.3214 - val_loss: 1.3180 - val_mae: 0.3114
# Epoch 11/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.8343 - mae: 0.3201 - val_loss: 1.3240 - val_mae: 0.3098
# Epoch 12/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.8393 - mae: 0.3214 - val_loss: 1.3125 - val_mae: 0.3071
# Epoch 13/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.8282 - mae: 0.3185 - val_loss: 1.3233 - val_mae: 0.3049
# Epoch 14/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.8214 - mae: 0.3181 - val_loss: 1.3271 - val_mae: 0.3043
# Epoch 15/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.8167 - mae: 0.3186 - val_loss: 1.3286 - val_mae: 0.3114
# Epoch 16/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.8167 - mae: 0.3163 - val_loss: 1.3191 - val_mae: 0.3072
# Epoch 17/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.8106 - mae: 0.3162 - val_loss: 1.3256 - val_mae: 0.3043

# %%
y_pred_scaled = model.predict(X_test)

y_pred = target_scaler.inverse_transform(y_pred_scaled)
y_test_actual = target_scaler.inverse_transform(y_test)

# No negative rainfall
y_pred = np.clip(y_pred, 0, None)
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
from sklearn.metrics import (
    r2_score,
    mean_squared_error,
    mean_absolute_error,
    median_absolute_error
)

mse   = mean_squared_error(y_test_actual, y_pred)
rmse  = np.sqrt(mse)
mae   = mean_absolute_error(y_test_actual, y_pred)
medae = median_absolute_error(y_test_actual, y_pred)
r2    = r2_score(y_test_actual, y_pred)

print("\nDetailed GRU Evaluation Metrics")
print("R²     :", round(r2, 4))
print("MSE    :", round(mse, 4))
print("RMSE   :", round(rmse, 4))
print("MAE    :", round(mae, 4))
print("MedAE  :", round(medae, 4))
# Out:
# Detailed GRU Evaluation Metrics
# R²     : 0.0493
# MSE    : 0.1847
# RMSE   : 0.4297
# MAE    : 0.115
# MedAE  : 0.0371

# %%
plt.figure(figsize=(12,5))
plt.plot(y_test_actual[:200], label="Actual")
plt.plot(y_pred[:200], label="Predicted")
plt.legend()
plt.title("GRU Rainfall Prediction")
plt.show()

# %%
latest_sequence_raw = df[feature_cols].tail(sequence_length)

latest_sequence_scaled = feature_scaler.transform(latest_sequence_raw)

latest_sequence_scaled = latest_sequence_scaled.reshape(1, sequence_length, len(feature_cols))

pred_scaled = model.predict(latest_sequence_scaled)

pred_real = target_scaler.inverse_transform(pred_scaled)

pred_real = np.clip(pred_real, 0, None)

print("\nPredicted Rainfall for Next Time Step:")
print(f"{pred_real[0][0]:.4f} mm")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Predicted Rainfall for Next Time Step:
# 0.1310 mm
