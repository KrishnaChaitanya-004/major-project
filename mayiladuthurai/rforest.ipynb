# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("mayiladuthurai.csv")
df = df.dropna()
df = df.sort_values("time")
df.reset_index(drop=True, inplace=True)

df.head()
# Out:
#                   time  temperature   dewpoint    pressure    wind_u  \
# 0  2021-01-01 00:00:00    23.894318  21.283966  1009.98627 -0.926916
# 1  2021-01-01 06:00:00    28.487091  21.479126  1012.44440 -3.790299
# 2  2021-01-01 12:00:00    27.083588  22.786652  1009.75120 -2.576442
# 3  2021-01-01 18:00:00    24.325470  21.151947  1011.69120 -1.303072
# 4  2021-01-02 00:00:00    23.896759  20.925568  1009.87000  0.327197
#
#      wind_v  cloud_cover  humidity   rain_mm
# 0 -3.659283     0.376667  85.34430  0.000000
# 1 -4.436192     0.974971  65.83926  0.001907
# 2 -3.394537     1.000001  77.38841  0.017067
# 3 -3.810934     0.990979  82.49335  0.000000
# 4 -3.703316     1.000001  83.47469  0.007248

# %%
feature_cols = [
    "temperature",
    "dewpoint",
    "pressure",
    "wind_u",
    "wind_v",
    "cloud_cover",
    "humidity"
]

target_col = "rain_mm"

X = df[feature_cols].values
y = df[target_col].values

# %%
split_index = int(len(X) * 0.8)

X_train = X[:split_index]
X_test  = X[split_index:]

y_train = y[:split_index]
y_test  = y[split_index:]

# %%
rf = RandomForestRegressor(
    n_estimators=200,
    max_depth=None,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, n_jobs=-1, random_state=42)

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import (
    r2_score,
    mean_squared_error,
    mean_absolute_error,
    median_absolute_error
)

mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_test, y_pred)
medae = median_absolute_error(y_test, y_pred)
r2   = r2_score(y_test, y_pred)

print("Model Evaluation Results")
print("R²     :", round(r2, 4))
print("MSE    :", round(mse, 4))
print("RMSE   :", round(rmse, 4))
print("MAE    :", round(mae, 4))
print("MedAE  :", round(medae, 4))
# Out:
# Model Evaluation Results
# R²     : 0.0673
# MSE    : 0.1497
# RMSE   : 0.3869
# MAE    : 0.1104
# MedAE  : 0.0215

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
plt.plot(y_test[:200], label="Actual")
plt.plot(y_pred[:200], label="Predicted")
plt.legend()
plt.title("Random Forest Rainfall Prediction")
plt.show()
