# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("tiruvarur.csv")
df = df.dropna()
df = df.sort_values("time")
df.reset_index(drop=True, inplace=True)

df.head()
# Out:
#                   time  temperature   dewpoint    pressure    wind_u  \
# 0  2021-01-01 00:00:00    23.950348  21.513580  1009.68250 -1.082067
# 1  2021-01-01 06:00:00    28.642670  21.212585  1012.16815 -3.838883
# 2  2021-01-01 12:00:00    27.019745  22.742737  1009.54940 -2.544398
# 3  2021-01-01 18:00:00    24.588165  21.212463  1011.40564 -1.383028
# 4  2021-01-02 00:00:00    24.156403  21.033844  1009.55190  0.175464
#
#      wind_v  cloud_cover   humidity   rain_mm
# 0 -3.762676     0.334507  86.262184  0.000000
# 1 -4.441441     0.986522  64.190040  0.000000
# 2 -3.397222     1.000001  77.472550  0.026146
# 3 -3.788473     0.994447  81.508290  0.000000
# 4 -3.769356     0.998022  82.731766  0.005053

# %%
feature_cols = [
    "temperature",
    "dewpoint",
    "pressure",
    "wind_u",
    "wind_v",
    "cloud_cover",
    "humidity"
]

target_col = "rain_mm"

X = df[feature_cols].values
y = df[target_col].values

# %%
split_index = int(len(X) * 0.8)

X_train = X[:split_index]
X_test  = X[split_index:]

y_train = y[:split_index]
y_test  = y[split_index:]

# %%
rf = RandomForestRegressor(
    n_estimators=200,
    max_depth=None,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, n_jobs=-1, random_state=42)

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import (
    r2_score,
    mean_squared_error,
    mean_absolute_error,
    median_absolute_error
)

mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_test, y_pred)
medae = median_absolute_error(y_test, y_pred)
r2   = r2_score(y_test, y_pred)

print("Model Evaluation Results")
print("R²     :", round(r2, 4))
print("MSE    :", round(mse, 4))
print("RMSE   :", round(rmse, 4))
print("MAE    :", round(mae, 4))
print("MedAE  :", round(medae, 4))
# Out:
# Model Evaluation Results
# R²     : 0.0628
# MSE    : 0.2205
# RMSE   : 0.4696
# MAE    : 0.1197
# MedAE  : 0.0253

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
plt.plot(y_test[:200], label="Actual")
plt.plot(y_pred[:200], label="Predicted")
plt.legend()
plt.title("Random Forest Rainfall Prediction")
plt.show()
