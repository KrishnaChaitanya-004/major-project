# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("thanjavur.csv")
df = df.dropna()
df = df.sort_values("time")
df.reset_index(drop=True, inplace=True)

df.head()
# Out:
#                   time  temperature   dewpoint    pressure    wind_u  \
# 0  2021-01-01 00:00:00    22.632599  21.084442  1004.29877 -0.775915
# 1  2021-01-01 06:00:00    28.455841  21.326385  1006.67880 -3.374894
# 2  2021-01-01 12:00:00    27.551117  22.370240  1003.91565 -2.210048
# 3  2021-01-01 18:00:00    23.376740  21.009369  1006.02185 -1.224520
# 4  2021-01-02 00:00:00    23.260040  20.113922  1004.27625 -0.034131
#
#      wind_v  cloud_cover   humidity   rain_mm
# 0 -3.779400     0.204143  90.982080  0.000000
# 1 -4.329747     0.990314  65.344660  0.050917
# 2 -2.450689     0.990087  73.417015  0.000000
# 3 -3.022116     0.988587  86.575450  0.000000
# 4 -3.566597     0.925161  82.505140  0.000000

# %%
feature_cols = [
    "temperature",
    "dewpoint",
    "pressure",
    "wind_u",
    "wind_v",
    "cloud_cover",
    "humidity"
]

target_col = "rain_mm"

X = df[feature_cols].values
y = df[target_col].values

# %%
split_index = int(len(X) * 0.8)

X_train = X[:split_index]
X_test  = X[split_index:]

y_train = y[:split_index]
y_test  = y[split_index:]

# %%
rf = RandomForestRegressor(
    n_estimators=200,
    max_depth=None,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, n_jobs=-1, random_state=42)

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import (
    r2_score,
    mean_squared_error,
    mean_absolute_error,
    median_absolute_error
)

mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_test, y_pred)
medae = median_absolute_error(y_test, y_pred)
r2   = r2_score(y_test, y_pred)

print("Model Evaluation Results")
print("R²     :", round(r2, 4))
print("MSE    :", round(mse, 4))
print("RMSE   :", round(rmse, 4))
print("MAE    :", round(mae, 4))
print("MedAE  :", round(medae, 4))
# Out:
# Model Evaluation Results
# R²     : 0.0941
# MSE    : 0.1
# RMSE   : 0.3163
# MAE    : 0.1002
# MedAE  : 0.0202

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
plt.plot(y_test[:200], label="Actual")
plt.plot(y_pred[:200], label="Predicted")
plt.legend()
plt.title("Random Forest Rainfall Prediction")
plt.show()
