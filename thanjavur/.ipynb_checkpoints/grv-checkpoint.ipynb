# %%
# ================================
# FIX ALL RANDOMNESS
# ================================
import os
import random
import numpy as np
import tensorflow as tf

SEED = 42

os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Make TensorFlow deterministic (important)
os.environ["TF_DETERMINISTIC_OPS"] = "1"
# ================================
# STEP 1 — Imports
# ================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# ================================
# STEP 2 — Load Data
# ================================
df = pd.read_csv("thanjavur.csv")   # <-- change file
df = df.sort_values("time")

df["time"] = pd.to_datetime(df["time"])

# ================================
# STEP 3 — Feature Engineering
# ================================
df["hour"] = df["time"].dt.hour
df["month"] = df["time"].dt.month

df["hour_sin"]  = np.sin(2 * np.pi * df["hour"] / 24)
df["hour_cos"]  = np.cos(2 * np.pi * df["hour"] / 24)
df["month_sin"] = np.sin(2 * np.pi * df["month"] / 12)
df["month_cos"] = np.cos(2 * np.pi * df["month"] / 12)

feature_cols = [
    "temperature",
    "dewpoint",
    "pressure",
    "wind_u",
    "wind_v",
    "cloud_cover",
    "humidity",
    "hour_sin",
    "hour_cos",
    "month_sin",
    "month_cos"
]

target_col = "rain_mm"

# ================================
# STEP 4 — Scale Features & Target Separately
# ================================
feature_scaler = StandardScaler()
target_scaler = StandardScaler()

X_scaled = feature_scaler.fit_transform(df[feature_cols])
y_scaled = target_scaler.fit_transform(df[[target_col]])

# ================================
# STEP 5 — Create Sequences
# ================================
sequence_length = 12   # 12 timesteps (72 hours)

def create_sequences(X, y, seq_len):
    Xs, ys = [], []
    for i in range(len(X) - seq_len):
        Xs.append(X[i:i+seq_len])
        ys.append(y[i+seq_len])
    return np.array(Xs), np.array(ys)

X_seq, y_seq = create_sequences(X_scaled, y_scaled, sequence_length)

# ================================
# STEP 6 — Time-based Split (80–20)
# ================================
split_index = int(len(X_seq) * 0.8)

X_train, X_test = X_seq[:split_index], X_seq[split_index:]
y_train, y_test = y_seq[:split_index], y_seq[split_index:]

# ================================
# STEP 7 — Build GRU Model
# ================================
model = Sequential([
    GRU(64, return_sequences=True, input_shape=(sequence_length, X_train.shape[2])),
    Dropout(0.2),
    GRU(32),
    Dropout(0.2),
    Dense(16, activation="relu"),
    Dense(1)
])

model.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

model.summary()

# ================================
# STEP 8 — Train
# ================================
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

history = model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=64,
    validation_data=(X_test, y_test),
    callbacks=[early_stop],
    verbose=1
)

# ================================
# STEP 9 — Predict & Inverse Transform
# ================================
y_pred_scaled = model.predict(X_test)

y_pred = target_scaler.inverse_transform(y_pred_scaled)
y_test_actual = target_scaler.inverse_transform(y_test)

# No negative rainfall
y_pred = np.clip(y_pred, 0, None)

# ================================
# STEP 10 — Evaluate
# ================================
mae = mean_absolute_error(y_test_actual, y_pred)
rmse = np.sqrt(mean_squared_error(y_test_actual, y_pred))

print("\nGRU Baseline Results")
print("MAE  :", round(mae, 4))
print("RMSE :", round(rmse, 4))

# ================================
# STEP 11 — Plot
# ================================
plt.figure(figsize=(12,5))
plt.plot(y_test_actual[:200], label="Actual")
plt.plot(y_pred[:200], label="Predicted")
plt.legend()
plt.title("GRU Rainfall Prediction")
plt.show()
# Out:
# /home/kc/py312/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_4 (GRU)                     │ (None, 12, 64)         │        14,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 12, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_5 (GRU)                     │ (None, 32)             │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,737 (96.63 KB)
#  Trainable params: 24,737 (96.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 87/90 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8567 - mae: 0.3917
# 2026-02-12 19:57:41.661127: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0002 - mae: 0.3965 - val_loss: 0.8674 - val_mae: 0.3331
# Epoch 2/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9715 - mae: 0.3849 - val_loss: 0.8680 - val_mae: 0.3242
# Epoch 3/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9502 - mae: 0.3736 - val_loss: 0.8702 - val_mae: 0.3130
# Epoch 4/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9319 - mae: 0.3640 - val_loss: 0.8727 - val_mae: 0.3103
# Epoch 5/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9327 - mae: 0.3657 - val_loss: 0.8704 - val_mae: 0.3275
# Epoch 6/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9251 - mae: 0.3619 - val_loss: 0.8708 - val_mae: 0.3267
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 7s 169ms/step
# 2026-02-12 19:57:46.873707: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
#
# GRU Baseline Results
# MAE  : 0.128
# RMSE : 0.3579
